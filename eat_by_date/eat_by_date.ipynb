# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import json
import requests

# %%
categories=['dairy','drinks','fruits','grains','other','proteins','vegetables']

# %%
href_dict = []

for category in categories:
    print(f"Scraping category: {category}")
    url = f'https://eatbydate.com/{category}'
    html = urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')

    data = []

    fusion_columns = soup.find_all('ul', {'class': 'sub-menu'})

    for fusion_column in fusion_columns:
        links = fusion_column.find_all('a')

        for link in links:
            href = link.get('href')
            text = link.text.strip()
            data.append({"category": category, "sub_category": text, "href": href})

    # Filter out the entries with sub_category equal to "Oil"
    data = [entry for entry in data if entry["sub_category"] != "Oil"] 

    # Extend the datalist with the data for the current category
    href_dict.extend(data)

with open('eat_by_date_href.json', "w") as json_file:
    json.dump(href_dict, json_file, indent=4)
# Out:
# Scraping category: dairy
# Scraping category: drinks
# Scraping category: fruits
# Scraping category: grains
# Scraping category: other
# Scraping category: proteins
# Scraping category: vegetables
# [{'category': 'dairy', 'sub_category': 'Butter and Margarine', 'href': '/dairy/spreads/'}, {'category': 'dairy', 'sub_category': 'Cheese', 'href': '/dairy/cheese/'}, {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/dairy/eggs/'}, {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Milk & Cream', 'href': '/dairy/milk/'}, {'category': 'dairy', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}, {'category': 'dairy', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}, {'category': 'dairy', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}, {'category': 'dairy', 'sub_category': 'Pudding', 'href': '/dairy/pudding-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Sour Cream', 'href': '/dairy/sour-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Yogurt', 'href': '/dairy/yogurt-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}, {'category': 'dairy', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}, {'category': 'dairy', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}, {'category': 'dairy', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}, {'category': 'dairy', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}, {'category':  ...

# %%
data_list=[]
for item in href_dict:
    # Construct the full URL
    url = "https://eatbydate.com" + item['href']
    # Send a GET request to the URL
    response = requests.get(url)
    # Parse the HTML content
    soup = BeautifulSoup(response.text, "html.parser")
    # Find the table containing shelf life data
    table = soup.find("table")
    if table:
        rows = table.find_all("tr")
        if rows:
            second_heading_index = next((idx for idx, row in enumerate(rows) if row.find("th") and row.find("th").text.strip() == "(Opened)"), None)
            if second_heading_index is not None:
                headers_1 = [header.get_text(strip=True).lower() for header in rows[0].find_all("th")]
                for row in rows[1:second_heading_index]:
                    data_dict = {}
                    cells = row.find_all("td")
                    if cells:
                        for idx, cell in enumerate(cells):
                            data_dict[headers_1[idx]] = cell.get_text(strip=True)
                        if any(data_dict.values()):
                            data_list.append(data_dict)
                headers_2 = [header.get_text(strip=True).lower() for header in rows[second_heading_index].find_all("th")]
                for row in rows[second_heading_index+1:]:
                    data_dict = {}
                    cells = row.find_all("td")
                    if cells:
                        for idx, cell in enumerate(cells):
                            data_dict[headers_2[idx]] = cell.get_text(strip=True)
                        if any(data_dict.values()):
                            data_list.append(data_dict)
            else:
                headers = [header.get_text(strip=True).lower() for header in rows[0].find_all("th")]
                for row in rows[1:]:
                    data_dict = {}
                    cells = row.find_all("td")
                    if cells:
                        for idx, cell in enumerate(cells):
                            data_dict[headers[idx]] = cell.get_text(strip=True)
                        if any(data_dict.values()):
                            data_list.append(data_dict)

    # Add fixed key-value pair for each item
    for entry in data_list:
        new_entry = {"category": item['category'],"subcategory":item['sub_category']}
        for key, value in entry.items():
            # Replace key name with item_description
            new_key = 'item_description' if key in ['(unopened)', '(opened)','(raw)','(unopened/opened)','open/unopened','(opened/unopened)','(whole)',''] else key
            new_entry[new_key] = value
        if any(key == '(unopened)' for key in entry.keys()):
            new_entry['type'] = 'unopened'
        if any(key == '(opened)' for key in entry.keys()):
            new_entry['type'] = 'opened'
        # If opened/unopened is not specified, set type as unknown
        if any(key in ['','(raw)','(unopened/opened)','open/unopened','(opened/unopened)','(whole)'] for key in entry.keys()):
            new_entry['type'] = 'unspecified'
        entry.clear()
        entry.update(new_entry)

# Dump the resulting data list to a JSON file
with open('eat_by_date.json', "w") as json_file:
    json.dump(data_list, json_file, indent=4)
# Out:
# {'category': 'dairy', 'sub_category': 'Butter and Margarine', 'href': '/dairy/spreads/'}
# {'category': 'dairy', 'sub_category': 'Cheese', 'href': '/dairy/cheese/'}
# {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/dairy/eggs/'}
# {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk & Cream', 'href': '/dairy/milk/'}
# {'category': 'dairy', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}
# {'category': 'dairy', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}
# {'category': 'dairy', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}
# {'category': 'dairy', 'sub_category': 'Pudding', 'href': '/dairy/pudding-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Sour Cream', 'href': '/dairy/sour-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Yogurt', 'href': '/dairy/yogurt-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}
# {'category': 'dairy', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}
# {'category': 'dairy', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}
# {'category': 'dairy', 'sub_category': 'Alcohol', 'href': '/drinks/alcohol/'}
# {'category': 'dairy', 'sub_category': 'Beer', 'href': '/drinks/alcohol/how-long-does-beer-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Champagne', 'href': '/drinks/alcohol/how-long-does-champagne-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Liquor', 'href': '/drinks/alcohol/alcohol-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Wine', 'href': '/drinks/alcohol/wine-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Coffee and Tea', 'href': '/drinks/coffee-tea-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Fruit Juice', 'href': '/drinks/fruit-juice-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Milk Drinks', 'href': '/drinks/milk/'}
# {'category': 'dairy', 'sub_category': 'Soft Drinks (Soda)', 'href': '/drinks/how-long-does-coke-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Sports Drinks', 'href': '/drinks/sport-drinks-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Water', 'href': '/drinks/how-long-does-water-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beer', 'href': '/drinks/alcohol/how-long-does-beer-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Champagne', 'href': '/drinks/alcohol/how-long-does-champagne-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Liquor', 'href': '/drinks/alcohol/alcohol-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Wine', 'href': '/drinks/alcohol/wine-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Canned Fruit', 'href': '/fruits/canned-fruit-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Cranberry Sauce', 'href': '/other/condiments/how-long-does-cranberry-sauce-last/'}
# {'category': 'dairy', 'sub_category': 'Dried Fruit', 'href': '/fruits/dried-fruit-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Fresh Fruits', 'href': '/fruits/fresh/'}
# {'category': 'dairy', 'sub_category': 'Apples', 'href': '/fruits/fresh/apples-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Avocados', 'href': '/fruits/fresh/how-long-do-avocados-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Bananas', 'href': '/fruits/fresh/bananas-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Blueberries', 'href': '/fruits/fresh/blueberries/'}
# {'category': 'dairy', 'sub_category': 'Cherries', 'href': '/fruits/fresh/cherries/'}
# {'category': 'dairy', 'sub_category': 'Coconuts', 'href': '/fruits/fresh/how-long-do-coconuts-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'dairy', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'dairy', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'dairy', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'dairy', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'dairy', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'dairy', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'dairy', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'dairy', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'dairy', 'sub_category': 'Frozen Fruit', 'href': '/fruits/frozen-fruit-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Apples', 'href': '/fruits/fresh/apples-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Avocados', 'href': '/fruits/fresh/how-long-do-avocados-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Bananas', 'href': '/fruits/fresh/bananas-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Blueberries', 'href': '/fruits/fresh/blueberries/'}
# {'category': 'dairy', 'sub_category': 'Cherries', 'href': '/fruits/fresh/cherries/'}
# {'category': 'dairy', 'sub_category': 'Coconuts', 'href': '/fruits/fresh/how-long-do-coconuts-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'dairy', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'dairy', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'dairy', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'dairy', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'dairy', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'dairy', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'dairy', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'dairy', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'dairy', 'sub_category': 'Canned Vegetables', 'href': '/vegetables/canned-vegetables-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Fresh Vegetables', 'href': '/vegetables/fresh-vegetables/'}
# {'category': 'dairy', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'dairy', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'dairy', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'dairy', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'dairy', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'dairy', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'dairy', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'dairy', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'dairy', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'dairy', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'dairy', 'sub_category': 'Frozen Vegetables', 'href': '/vegetables/frozen-vegetables-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'dairy', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'dairy', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'dairy', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'dairy', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'dairy', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'dairy', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'dairy', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'dairy', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'dairy', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'dairy', 'sub_category': 'Bread', 'href': '/grains/baked-goods/bread-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Cereals', 'href': '/grains/cereal/'}
# {'category': 'dairy', 'sub_category': 'Lasagna', 'href': '/grains/lasagna/'}
# {'category': 'dairy', 'sub_category': 'Pasta', 'href': '/grains/pasta-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Pizza', 'href': '/grains/pizza-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Rice', 'href': '/grains/rice-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Stuffing', 'href': '/grains/baked-goods/stuffing-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Tortillas', 'href': '/grains/baked-goods/how-long-do-tortillas-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beans, Peas & Tofu', 'href': '/proteins/beans-peas/'}
# {'category': 'dairy', 'sub_category': 'Deli Meat', 'href': '/proteins/meats/deli-meat-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Meats', 'href': '/proteins/meats/'}
# {'category': 'dairy', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'dairy', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'dairy', 'sub_category': 'Nuts and Seeds', 'href': '/proteins/nuts/'}
# {'category': 'dairy', 'sub_category': 'Poultry', 'href': '/proteins/poultry/'}
# {'category': 'dairy', 'sub_category': 'Seafood', 'href': '/proteins/seafood/'}
# {'category': 'dairy', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'dairy', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'dairy', 'sub_category': 'Baking Products', 'href': '/other/baking/'}
# {'category': 'dairy', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'dairy', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'dairy', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'dairy', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'dairy', 'sub_category': 'Condiments', 'href': '/other/condiments/'}
# {'category': 'dairy', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'dairy', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'dairy', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
# {'category': 'dairy', 'sub_category': 'Dry Ice', 'href': '/other/dry-ice/'}
# {'category': 'dairy', 'sub_category': 'Pesto', 'href': '/pesto/'}
# {'category': 'dairy', 'sub_category': 'Salad Dressing', 'href': '/other/condiments/bottled-salad-dressing-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Snacks', 'href': '/other/snacks/'}
# {'category': 'dairy', 'sub_category': 'Spaghetti Sauce', 'href': '/vegetables/fresh-vegetables/spaghetti-sauce-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Spice Menu', 'href': '/other/spice-menu/'}
# {'category': 'dairy', 'sub_category': 'Sweets', 'href': '/other/sweets/'}
# {'category': 'dairy', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'dairy', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'dairy', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'dairy', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'dairy', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'dairy', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'dairy', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'dairy', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'dairy', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
# {'category': 'drinks', 'sub_category': 'Butter and Margarine', 'href': '/dairy/spreads/'}
# {'category': 'drinks', 'sub_category': 'Cheese', 'href': '/dairy/cheese/'}
# {'category': 'drinks', 'sub_category': 'Eggs', 'href': '/dairy/eggs/'}
# {'category': 'drinks', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk & Cream', 'href': '/dairy/milk/'}
# {'category': 'drinks', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}
# {'category': 'drinks', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}
# {'category': 'drinks', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}
# {'category': 'drinks', 'sub_category': 'Pudding', 'href': '/dairy/pudding-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Sour Cream', 'href': '/dairy/sour-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Yogurt', 'href': '/dairy/yogurt-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}
# {'category': 'drinks', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}
# {'category': 'drinks', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}
# {'category': 'drinks', 'sub_category': 'Alcohol', 'href': '/drinks/alcohol/'}
# {'category': 'drinks', 'sub_category': 'Beer', 'href': '/drinks/alcohol/how-long-does-beer-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Champagne', 'href': '/drinks/alcohol/how-long-does-champagne-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Liquor', 'href': '/drinks/alcohol/alcohol-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Wine', 'href': '/drinks/alcohol/wine-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Coffee and Tea', 'href': '/drinks/coffee-tea-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Fruit Juice', 'href': '/drinks/fruit-juice-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Milk Drinks', 'href': '/drinks/milk/'}
# {'category': 'drinks', 'sub_category': 'Soft Drinks (Soda)', 'href': '/drinks/how-long-does-coke-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Sports Drinks', 'href': '/drinks/sport-drinks-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Water', 'href': '/drinks/how-long-does-water-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beer', 'href': '/drinks/alcohol/how-long-does-beer-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Champagne', 'href': '/drinks/alcohol/how-long-does-champagne-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Liquor', 'href': '/drinks/alcohol/alcohol-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Wine', 'href': '/drinks/alcohol/wine-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Canned Fruit', 'href': '/fruits/canned-fruit-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Cranberry Sauce', 'href': '/other/condiments/how-long-does-cranberry-sauce-last/'}
# {'category': 'drinks', 'sub_category': 'Dried Fruit', 'href': '/fruits/dried-fruit-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Fresh Fruits', 'href': '/fruits/fresh/'}
# {'category': 'drinks', 'sub_category': 'Apples', 'href': '/fruits/fresh/apples-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Avocados', 'href': '/fruits/fresh/how-long-do-avocados-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Bananas', 'href': '/fruits/fresh/bananas-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Blueberries', 'href': '/fruits/fresh/blueberries/'}
# {'category': 'drinks', 'sub_category': 'Cherries', 'href': '/fruits/fresh/cherries/'}
# {'category': 'drinks', 'sub_category': 'Coconuts', 'href': '/fruits/fresh/how-long-do-coconuts-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'drinks', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'drinks', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'drinks', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'drinks', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'drinks', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'drinks', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'drinks', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'drinks', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'drinks', 'sub_category': 'Frozen Fruit', 'href': '/fruits/frozen-fruit-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Apples', 'href': '/fruits/fresh/apples-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Avocados', 'href': '/fruits/fresh/how-long-do-avocados-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Bananas', 'href': '/fruits/fresh/bananas-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Blueberries', 'href': '/fruits/fresh/blueberries/'}
# {'category': 'drinks', 'sub_category': 'Cherries', 'href': '/fruits/fresh/cherries/'}
# {'category': 'drinks', 'sub_category': 'Coconuts', 'href': '/fruits/fresh/how-long-do-coconuts-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'drinks', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'drinks', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'drinks', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'drinks', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'drinks', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'drinks', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'drinks', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'drinks', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'drinks', 'sub_category': 'Canned Vegetables', 'href': '/vegetables/canned-vegetables-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Fresh Vegetables', 'href': '/vegetables/fresh-vegetables/'}
# {'category': 'drinks', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'drinks', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'drinks', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'drinks', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'drinks', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'drinks', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'drinks', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'drinks', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'drinks', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'drinks', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'drinks', 'sub_category': 'Frozen Vegetables', 'href': '/vegetables/frozen-vegetables-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'drinks', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'drinks', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'drinks', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'drinks', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'drinks', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'drinks', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'drinks', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'drinks', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'drinks', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'drinks', 'sub_category': 'Bread', 'href': '/grains/baked-goods/bread-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Cereals', 'href': '/grains/cereal/'}
# {'category': 'drinks', 'sub_category': 'Lasagna', 'href': '/grains/lasagna/'}
# {'category': 'drinks', 'sub_category': 'Pasta', 'href': '/grains/pasta-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Pizza', 'href': '/grains/pizza-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Rice', 'href': '/grains/rice-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Stuffing', 'href': '/grains/baked-goods/stuffing-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Tortillas', 'href': '/grains/baked-goods/how-long-do-tortillas-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beans, Peas & Tofu', 'href': '/proteins/beans-peas/'}
# {'category': 'drinks', 'sub_category': 'Deli Meat', 'href': '/proteins/meats/deli-meat-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Meats', 'href': '/proteins/meats/'}
# {'category': 'drinks', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'drinks', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'drinks', 'sub_category': 'Nuts and Seeds', 'href': '/proteins/nuts/'}
# {'category': 'drinks', 'sub_category': 'Poultry', 'href': '/proteins/poultry/'}
# {'category': 'drinks', 'sub_category': 'Seafood', 'href': '/proteins/seafood/'}
# {'category': 'drinks', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'drinks', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'drinks', 'sub_category': 'Baking Products', 'href': '/other/baking/'}
# {'category': 'drinks', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'drinks', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'drinks', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'drinks', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'drinks', 'sub_category': 'Condiments', 'href': '/other/condiments/'}
# {'category': 'drinks', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'drinks', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'drinks', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
# {'category': 'drinks', 'sub_category': 'Dry Ice', 'href': '/other/dry-ice/'}
# {'category': 'drinks', 'sub_category': 'Pesto', 'href': '/pesto/'}
# {'category': 'drinks', 'sub_category': 'Salad Dressing', 'href': '/other/condiments/bottled-salad-dressing-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Snacks', 'href': '/other/snacks/'}
# {'category': 'drinks', 'sub_category': 'Spaghetti Sauce', 'href': '/vegetables/fresh-vegetables/spaghetti-sauce-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Spice Menu', 'href': '/other/spice-menu/'}
# {'category': 'drinks', 'sub_category': 'Sweets', 'href': '/other/sweets/'}
# {'category': 'drinks', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'drinks', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'drinks', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'drinks', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'drinks', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'drinks', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'drinks', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'drinks', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'drinks', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
# {'category': 'fruits', 'sub_category': 'Butter and Margarine', 'href': '/dairy/spreads/'}
# {'category': 'fruits', 'sub_category': 'Cheese', 'href': '/dairy/cheese/'}
# {'category': 'fruits', 'sub_category': 'Eggs', 'href': '/dairy/eggs/'}
# {'category': 'fruits', 'sub_category': 'Eggs', 'href': '/eggs-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Hard Boiled Eggs', 'href': '/hard-boiled-eggs-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Milk & Cream', 'href': '/dairy/milk/'}
# {'category': 'fruits', 'sub_category': 'Buttermilk', 'href': '/dairy/milk/buttermilk/'}
# {'category': 'fruits', 'sub_category': 'Dairy (Coffee) Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Coffee Mate', 'href': '/dairy/milk/how-long-does-coffee-mate-last-shelf-life/'}
# {'category': 'fruits', 'sub_category': 'Cream', 'href': '/dairy/milk/dairy-coffee-cream-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Egg Nog', 'href': '/dairy/milk/how-long-does-egg-nog-last-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Ensure', 'href': '/drinks/ensure/'}
# {'category': 'fruits', 'sub_category': 'Evaporated Milk', 'href': '/dairy/milk/how-long-does-evaporated-milk-last-shelf-life/'}
# {'category': 'fruits', 'sub_category': 'Ice Cream', 'href': '/dairy/ice-cream-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Infant Formula', 'href': '/dairy/milk/how-long-does-infant-formula-last-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Milk', 'href': '/dairy/milk/milk-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Milk Alternatives', 'href': '/dairy/milk/soy-rice-almond-milk-substitutes-shelf-life-expiration-date/'}
# {'category': 'fruits', 'sub_category': 'Powdered Milk', 'href': '/dairy/milk/how-long-does-powdered-milk-last-shelf-life/'}
# {'category': 'fruits', 'sub_category': 'Sweetened Condensed Milk', 'href': '/dairy/milk/how-long-does-condensed-milk-last-shelf-life/'}
# {'category': 'fruits', 'sub_category': 'Whipped Cream', 'href': '/dairy/milk/whipped-cream/'}
# ...
# {'category': 'proteins', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'proteins', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'proteins', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'proteins', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'proteins', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'proteins', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'proteins', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'proteins', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'proteins', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'proteins', 'sub_category': 'Frozen Fruit', 'href': '/fruits/frozen-fruit-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Apples', 'href': '/fruits/fresh/apples-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Avocados', 'href': '/fruits/fresh/how-long-do-avocados-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Bananas', 'href': '/fruits/fresh/bananas-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Blueberries', 'href': '/fruits/fresh/blueberries/'}
# {'category': 'proteins', 'sub_category': 'Cherries', 'href': '/fruits/fresh/cherries/'}
# {'category': 'proteins', 'sub_category': 'Coconuts', 'href': '/fruits/fresh/how-long-do-coconuts-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Figs', 'href': '/fruits/fresh/figs/'}
# {'category': 'proteins', 'sub_category': 'Grapes', 'href': '/fruits/fresh/grapes/'}
# {'category': 'proteins', 'sub_category': 'Lemons', 'href': '/fruits/fresh/how-long-do-lemons-last/'}
# {'category': 'proteins', 'sub_category': 'Limes', 'href': '/fruits/fresh/how-long-do-limes-last/'}
# {'category': 'proteins', 'sub_category': 'Pineapples', 'href': '/fruits/fresh/pineapples/'}
# {'category': 'proteins', 'sub_category': 'Pomegranate', 'href': '/fruits/fresh/pomegranate/'}
# {'category': 'proteins', 'sub_category': 'Pumpkin', 'href': '/fruits/fresh/how-long-does-pumpkin-last/'}
# {'category': 'proteins', 'sub_category': 'Strawberries', 'href': '/fruits/fresh/how-long-do-strawberries-last/'}
# {'category': 'proteins', 'sub_category': 'Tomatoes', 'href': '/fruits/fresh/tomatoes-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Watermelon', 'href': '/fruits/fresh/watermelon/'}
# {'category': 'proteins', 'sub_category': 'Canned Vegetables', 'href': '/vegetables/canned-vegetables-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Fresh Vegetables', 'href': '/vegetables/fresh-vegetables/'}
# {'category': 'proteins', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'proteins', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'proteins', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'proteins', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'proteins', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'proteins', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'proteins', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'proteins', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'proteins', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'proteins', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'proteins', 'sub_category': 'Frozen Vegetables', 'href': '/vegetables/frozen-vegetables-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Asparagus', 'href': '/vegetables/fresh-vegetables/asparagus/'}
# {'category': 'proteins', 'sub_category': 'Bell Peppers', 'href': '/vegetables/fresh-vegetables/bell-peppers/'}
# {'category': 'proteins', 'sub_category': 'Broccoli', 'href': '/vegetables/fresh-vegetables/broccoli/'}
# {'category': 'proteins', 'sub_category': 'Carrots', 'href': '/vegetables/fresh-vegetables/how-long-do-carrots-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Cauliflower', 'href': '/vegetables/fresh-vegetables/cauliflower/'}
# {'category': 'proteins', 'sub_category': 'Celery', 'href': '/vegetables/fresh-vegetables/how-long-does-celery-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Corn', 'href': '/vegetables/fresh-vegetables/corn/'}
# {'category': 'proteins', 'sub_category': 'Cucumbers', 'href': '/vegetables/fresh-vegetables/how-long-do-cucumbers-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Garlic', 'href': '/vegetables/fresh-vegetables/how-long-does-garlic-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Kale', 'href': '/vegetables/fresh-vegetables/kale/'}
# {'category': 'proteins', 'sub_category': 'Mushrooms', 'href': '/vegetables/fresh-vegetables/mushrooms/'}
# {'category': 'proteins', 'sub_category': 'Onions', 'href': '/vegetables/fresh-vegetables/how-long-do-onions-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Potatoes', 'href': '/vegetables/fresh-vegetables/potatoes-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Salad', 'href': '/vegetables/fresh-vegetables/salad-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Spinach', 'href': '/vegetables/fresh-vegetables/spinach/'}
# {'category': 'proteins', 'sub_category': 'Squash', 'href': '/vegetables/fresh-vegetables/how-long-does-summer-squash-last/'}
# {'category': 'proteins', 'sub_category': 'Sweet Potatoes', 'href': '/vegetables/fresh-vegetables/how-long-do-sweet-potatoes-or-yams-last/'}
# {'category': 'proteins', 'sub_category': 'Bread', 'href': '/grains/baked-goods/bread-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Cereals', 'href': '/grains/cereal/'}
# {'category': 'proteins', 'sub_category': 'Lasagna', 'href': '/grains/lasagna/'}
# {'category': 'proteins', 'sub_category': 'Pasta', 'href': '/grains/pasta-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Pizza', 'href': '/grains/pizza-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Rice', 'href': '/grains/rice-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Stuffing', 'href': '/grains/baked-goods/stuffing-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Tortillas', 'href': '/grains/baked-goods/how-long-do-tortillas-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Beans, Peas & Tofu', 'href': '/proteins/beans-peas/'}
# {'category': 'proteins', 'sub_category': 'Deli Meat', 'href': '/proteins/meats/deli-meat-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Meats', 'href': '/proteins/meats/'}
# {'category': 'proteins', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'proteins', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'proteins', 'sub_category': 'Nuts and Seeds', 'href': '/proteins/nuts/'}
# {'category': 'proteins', 'sub_category': 'Poultry', 'href': '/proteins/poultry/'}
# {'category': 'proteins', 'sub_category': 'Seafood', 'href': '/proteins/seafood/'}
# {'category': 'proteins', 'sub_category': 'Bacon', 'href': '/proteins/meats/bacon-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Beef', 'href': '/proteins/meats/beef-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Beef Jerky', 'href': '/proteins/meats/does-beef-jerky-go-bad/'}
# {'category': 'proteins', 'sub_category': 'Canned Meat', 'href': '/proteins/meats/how-long-does-canned-meat-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Ham', 'href': '/proteins/meats/ham-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Hamburgers', 'href': '/proteins/meats/hamburgers-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Hot Dogs', 'href': '/proteins/meats/hot-dogs-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Pork', 'href': '/proteins/meats/how-long-does-pork-last/'}
# {'category': 'proteins', 'sub_category': 'Baking Products', 'href': '/other/baking/'}
# {'category': 'proteins', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'proteins', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'proteins', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'proteins', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'proteins', 'sub_category': 'Condiments', 'href': '/other/condiments/'}
# {'category': 'proteins', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'proteins', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'proteins', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
# {'category': 'proteins', 'sub_category': 'Dry Ice', 'href': '/other/dry-ice/'}
# {'category': 'proteins', 'sub_category': 'Pesto', 'href': '/pesto/'}
# {'category': 'proteins', 'sub_category': 'Salad Dressing', 'href': '/other/condiments/bottled-salad-dressing-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Snacks', 'href': '/other/snacks/'}
# {'category': 'proteins', 'sub_category': 'Spaghetti Sauce', 'href': '/vegetables/fresh-vegetables/spaghetti-sauce-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Spice Menu', 'href': '/other/spice-menu/'}
# {'category': 'proteins', 'sub_category': 'Sweets', 'href': '/other/sweets/'}
# {'category': 'proteins', 'sub_category': 'Baking Powder', 'href': '/other/baking/baking-powder-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Baking Soda', 'href': '/other/baking/baking-soda-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Chocolate Syrup', 'href': '/other/sweets/how-long-does-chocolate-syrup-last/'}
# {'category': 'proteins', 'sub_category': 'Cocoa', 'href': '/other/sweets/how-long-does-cocoa-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Crisco', 'href': '/other/baking/how-long-does-crisco-last-shelf-life-expiration-date-storage-tips/'}
# {'category': 'proteins', 'sub_category': 'Cake Mix', 'href': '/other/baking/cake-mix-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Cookie Dough', 'href': '/other/baking/cookie-dough/'}
# {'category': 'proteins', 'sub_category': 'Flour', 'href': '/other/baking/how-long-does-flour-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Molasses', 'href': '/other/baking/how-long-does-molasses-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Yeast', 'href': '/other/baking/yeast/'}
# {'category': 'proteins', 'sub_category': 'BBQ Sauce', 'href': '/other/condiments/how-long-does-bbq-sauce-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Coconut Oil', 'href': '/other/condiments/how-long-does-coconut-oil-last/'}
# {'category': 'proteins', 'sub_category': 'Fish Sauce', 'href': '/other/condiments/how-long-does-fish-sauce-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Jam', 'href': '/other/condiments/how-long-does-jam-last-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Ketchup', 'href': '/other/condiments/ketchup-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Mayonnaise', 'href': '/other/condiments/mayonnaise-shelf-life-expiration-date/'}
# {'category': 'proteins', 'sub_category': 'Mustard', 'href': '/other/condiments/how-long-does-mustard-last/'}
# {'category': 'proteins', 'sub_category': 'Nutella', 'href': '/other/condiments/how-long-does-nutella-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Oyster Sauce', 'href': '/other/condiments/how-long-does-oyster-sauce-last-shelf-life/'}
# {'category': 'proteins', 'sub_category': 'Vinegar', 'href': '/other/condiments/how-long-does-vinegar-last/'}
